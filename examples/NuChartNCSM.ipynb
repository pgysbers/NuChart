# %%
import sys
sys.path.append("../../")
from NuChart.src.NuChart import *
import pandas as pd
import numpy as np

# %%
nc = NuChart(55, 45, figsize=(14, 8))
nc.add_magic_numbers()

nc.plot_HardyTowner()

# %%
for Nmax in range(13):
    nc = NuChart(55,45, figsize=(14,8))
    nc.add_magic_numbers()
    nc.plot_ncsm(Nmax=Nmax, pmax=28, nmax=28)
    nc.plot_HardyTowner()
    nc.savefig(f'NCSMdim_Nmax{Nmax}.pdf')
